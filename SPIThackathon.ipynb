# %%
import numpy as np
import pandas as pd
from functools import reduce
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("retailer_stock.csv")

# %%
df.head()
# Out:
#   state_name district_name    sub_district  retailer_id dealership_nature  \
# 0     Punjab         Mansa           Mansa       132999  Private Retailer
# 1     Punjab         Mansa           Mansa       132999  Private Retailer
# 2     Punjab     Jalandhar  Jalandhar - II       115575  Private Retailer
# 3     Punjab     Jalandhar  Jalandhar - II       115575  Private Retailer
# 4     Punjab      Bathinda   Talwandi Sabo       121756  Private Retailer
#
#   company   plant       product  opening_balance  received_quantity  \
# 0  MOSAIC  MOSAIC  Imported DAP             2.75               0.00
# 1  MOSAIC  MOSAIC           MOP             0.00               1.25
# 2  MOSAIC  MOSAIC  Imported DAP            12.45               0.00
# 3  MOSAIC  MOSAIC           MOP            43.25              62.50
# 4  MOSAIC  MOSAIC  Imported DAP            14.50               0.00
#
#    sold_quantity  availabilty  closing_balance created_date     to_date  \
# ...

# %%
# taking stock sold as o/p variable

# %%
df['product_id'].unique()
# Out:
# array([71,  8])

# %%
df['retailer_id'].unique()
# Out:
# array([ 132999,  115575,  121756, ...,  839424,  637367, 1024369])

# %%
lst= [] 
lst = df['state_name'].unique()

# %%
df.describe()
# Out:
#         retailer_id  opening_balance  received_quantity  sold_quantity  \
# count  1.694030e+05    169403.000000      169403.000000  169403.000000
# mean   5.775738e+05         6.043394           1.004574       1.529360
# std    3.366478e+05        14.755006           6.430665       6.760378
# min    1.033130e+05         0.000000           0.000000       0.000000
# 25%    2.725770e+05         0.600000           0.000000       0.000000
# 50%    5.053340e+05         2.350000           0.000000       0.000000
# 75%    8.842190e+05         6.450000           0.000000       0.850000
# max    1.201723e+06       486.750000         392.750000     455.400000
#
#          availabilty  closing_balance     product_id
# count  169403.000000    169403.000000  169403.000000
# mean        5.518608         5.518608      32.891253
# std        14.228293        14.228293      30.799027
# min         0.000000         0.000000       8.000000
# 25%         0.500000         0.500000       8.000000
# ...

# %%
for lsst in lst:
    x = df[["retailer_id","state","product_id","sold_date"]]
    x = x.loc[x['state']==lsst] 
    x = x.dropna()
    x = x[["sold_date"]]
    x = x.sort_values(by=['sold_date'])
   # x.plot(kind ="line",x="sold_date", y = "sold_stock",figsize=(20,8),title=lsst+" Plot")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-0e4a2c705a13> in <module>
#       1 for lsst in lst:
# ----> 2     x = df[["retailer_id","state","product_id","sold_date"]]
#       3     x = x.loc[x['state']==lsst]
#       4     x = x.dropna()
#       5     x = x[["sold_date"]]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
x1 = x.copy()

from sklearn.preprocessing import LabelEncoder
#x1['state_coded'] = lb_make.fit_transform(x['state'])
#x1 = x1.drop(columns=['state'])
x1 = x1.dropna()
x1 #Results in appending a new column to df
# Out:
#          sold_date
# 108605  2019-03-23
# 221274  2019-08-07
# 221273  2019-08-11
# 217725  2019-09-11
# 221272  2019-09-11
# ...            ...
# 217716  2020-11-27
# 217715  2020-11-28
# 217905  2020-11-29
# 217714  2020-11-29
# 217713  2020-11-30
#
# [67 rows x 1 columns]

# %%
x1["year"]= pd.DatetimeIndex(x['sold_date']).year
x1["month"]= pd.DatetimeIndex(x['sold_date']).month
x1["day"]= pd.DatetimeIndex(x1['sold_date']).day
x1.drop(columns = ["sold_date"])

# %%
x1["state"] = df["state"]

# %%
x1
# Out:
#          sold_date  year  month  day  state
# 108605  2019-03-23  2019      3   23  Bihar
# 221274  2019-08-07  2019      8    7  Bihar
# 221273  2019-08-11  2019      8   11  Bihar
# 217725  2019-09-11  2019      9   11  Bihar
# 221272  2019-09-11  2019      9   11  Bihar
# ...            ...   ...    ...  ...    ...
# 217716  2020-11-27  2020     11   27  Bihar
# 217715  2020-11-28  2020     11   28  Bihar
# 217905  2020-11-29  2020     11   29  Bihar
# 217714  2020-11-29  2020     11   29  Bihar
# 217713  2020-11-30  2020     11   30  Bihar
#
# [67 rows x 5 columns]
